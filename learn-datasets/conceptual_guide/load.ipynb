# %%
# 2025/7/16
# zhangzhong
# https://huggingface.co/docs/datasets/loading
# TODO: read this if needed.

# %%
# This guide will show you how to load a dataset from:

# - The Hugging Face Hub
# - Local files
# - In-memory data
# - Offline
# - A specific slice of a split

# %%
# 1. Hugging Face Hub

from datasets import load_dataset
dataset = load_dataset("lhoestq/demo1")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /data2/zhangzhong/src/deep_learning/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:409, in hf_raise_for_status(response, endpoint_name)
#     408 try:
# --> 409     response.raise_for_status()
#     410 except HTTPError as e:
#
# File /data2/zhangzhong/src/deep_learning/.venv/lib/python3.12/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/datasets/lhoestq/demo1/resolve/87ecf163bedca9d80598b528940a9c4f99e14c11/demo1.py
#
# The above exception was the direct cause of the following exception:
#
# EntryNotFoundError                        Traceback (most recent call last)
# ...

# %%
# Some datasets may have more than one version based on Git tags, branches, or commits. Use the revision parameter to specify the dataset version you want to load:
dataset = load_dataset(
  "lhoestq/demo1",
  revision="main"  # tag name, or branch name, or commit hash
)

# %%
# 这么多花里胡哨的加载数据的方法，，，大概是用不上的
# A dataset loads by default all the data into the train split, or checks for mentions or split names in the data files names (e.g. “train”, “test” and “validation”). Use the data_files parameter to map data files to splits like train, validation and test:
# data_files = {"train": "train.csv", "test": "test.csv"}
# dataset = load_dataset("namespace/your_dataset_name", data_files=data_files)

# # You can also load a specific subset of the files with the data_files or data_dir parameter. These parameters can accept a relative path which resolves to the base path corresponding to where the dataset is loaded from.
# from datasets import load_dataset

# c4_subset = load_dataset("allenai/c4", data_files="en/c4-train.0000*-of-01024.json.gz")

# c4_subset = load_dataset("allenai/c4", data_dir="en")

# # The split parameter can also map a data file to a specific split:
# data_files = {"validation": "en/c4-validation.*.json.gz"}
# c4_validation = load_dataset("allenai/c4", data_files=data_files, split="validation")
# Out:
# ---------------------------------------------------------------------------
# DatasetNotFoundError                      Traceback (most recent call last)
# Cell In[5], line 4
#       1 # 这么多花里胡哨的加载数据的方法，，，大概是用不上的
#       2 # A dataset loads by default all the data into the train split, or checks for mentions or split names in the data files names (e.g. “train”, “test” and “validation”). Use the data_files parameter to map data files to splits like train, validation and test:
#       3 data_files = {"train": "train.csv", "test": "test.csv"}
# ----> 4 dataset = load_dataset("namespace/your_dataset_name", data_files=data_files)
#       6 # You can also load a specific subset of the files with the data_files or data_dir parameter. These parameters can accept a relative path which resolves to the base path corresponding to where the dataset is loaded from.
#       7 from datasets import load_dataset
#
# ...

# %%
# Multiprocessing
# When a dataset is made of several files (that we call “shards”),
# it is possible to significantly speed up the dataset downloading and preparation step.

from datasets import load_dataset

# You can choose how many processes you’d like to use to prepare a dataset in parallel using num_proc
# In this case, each process is given a subset of shards to prepare.
# imagenet = load_dataset(path="timm/imagenet-1k-wds", num_proc=8)
# ml_librispeech_spanish = load_dataset(path="facebook/multilingual_librispeech", name="spanish", num_proc=8)
# Out:
# ...
# Resolving data files:   0%|          | 0/64 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 9
#       5 from datasets import load_dataset
#       7 # You can choose how many processes you’d like to use to prepare a dataset in parallel using num_proc
#       8 # In this case, each process is given a subset of shards to prepare.
# ----> 9 imagenet = load_dataset(path="timm/imagenet-1k-wds", num_proc=8)
#      10 ml_librispeech_spanish = load_dataset(path="facebook/multilingual_librispeech", name="spanish", num_proc=8)
#
# File /data2/zhangzhong/src/deep_learning/.venv/lib/python3.12/site-packages/datasets/load.py:1412, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
# ...

# %%
# Offline mode
# set HF_HUB_OFFLINE=1 to enable

# %%
# Specify feature, define your onw labels with the Features class, ClassLabel

# %%
# Load from local and remote files
# Load from memory data

# %%
# https://huggingface.co/docs/datasets/loading#slice-splits
# 各种奇怪的slice方式
# You can also choose only to load specific slices of a split

# Concatenate a train and test split by:                split="train+test"
# Select specific rows of the train split:              split="train[10:20]"
# Or select a percentage of a split with:               split="train[:10%]"
# Select a combination of percentages from each split:  split="train[:10%]+train[-80%:]"
# creates 10-fold cross-validated splits.               split=[f"train[{k}%:{k+10}%]" for k in range(0, 100, 10)]
# ...
